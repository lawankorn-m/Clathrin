# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import pandas as pd
import math
import os
from sklearn.preprocessing import scale
from tensorflow.keras.models import Sequential, model_from_json
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import StratifiedKFold
from keras.regularizers import l2


# Function to map categorical probabilities to class labels
def categorical_probas_to_classes(p):
    return np.argmax(p, axis=1)


# Function to calculate performance metrics
def calculate_performance(test_num, pred_y, labels):
    tp, fp, tn, fn = 0, 0, 0, 0
    for index in range(test_num):
        if labels[index] == 1:
            if labels[index] == pred_y[index]:
                tp += 1
            else:
                fn += 1
        else:
            if labels[index] == pred_y[index]:
                tn += 1
            else:
                fp += 1

    acc = (tp + tn) / test_num
    precision = tp / (tp + fp + 1e-6)
    npv = tn / (tn + fn + 1e-6)
    sensitivity = tp / (tp + fn + 1e-6)
    specificity = tn / (tn + fp + 1e-6)
    mcc = (tp * tn - fp * fn) / (math.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)) + 1e-6)
    f1 = 2 * tp / (2 * tp + fp + fn + 1e-6)
    return acc, precision, npv, sensitivity, specificity, mcc, f1, tp, tn, fp, fn


# Function to define and return the CNN-BiLSTM model
def get_LSTM_model(input_dim, out_dim):
    model = Sequential()
    model.add(LSTM(int(input_dim/2), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(int(input_dim/4), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(int(input_dim/4), activation = 'relu'))
    model.add(Dense(int(input_dim/8), activation = 'relu'))
    model.add(Dense(out_dim, activation = 'softmax',name="Dense_2"))
    model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics =['accuracy'])
    return model



# Folder containing CSV files
input_dir = './New_/'
csv_files = [f for f in os.listdir(input_dir) if f.endswith('.csv')]

# Loop through each CSV file
for file_name in csv_files:
    base_name = os.path.splitext(file_name)[0]
    output_base_dir = f"./LSTM-{file_name}/"
    os.makedirs(output_base_dir, exist_ok=True)

    # Load data
    data_ = pd.read_csv(os.path.join(input_dir, file_name))
    data = data_.iloc[:, 1:]
    data = data.loc[0:2420]

    ones_vector1 = np.ones(1288)
    zeros_vector1 = np.zeros(1133)

    y = np.hstack((ones_vector1, zeros_vector1))
    X = scale(data)

    sepscores = []
    ytest = np.ones((1, 2)) * 0.5
    yscore = np.ones((1, 2)) * 0.5

    [sample_num, input_dim] = np.shape(X)
    out_dim = 2

    probas_cnn = []
    tprs_cnn = []
    sepscore_cnn = []

    # Callbacks for model training
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
    call = [EarlyStopping(monitor='val_loss', patience=25), reduce_lr]

    # 10-fold cross-validation
    skf = StratifiedKFold(n_splits=10, shuffle=True)
    for i, (train, test) in enumerate(skf.split(X, y)):
        clf_cnn = get_LSTM_model(input_dim, out_dim)
        X_train_cnn = np.reshape(X[train], (-1, 1, input_dim))
        X_test_cnn = np.reshape(X[test], (-1, 1, input_dim))
        y_test = to_categorical(y[test])
        ytest = np.vstack((ytest, y_test))
        y_test_tmp = y[test]

        # Training
        history = clf_cnn.fit(X_train_cnn, to_categorical(y[train]), validation_data=(X_test_cnn, y_test),
                              batch_size=8, epochs=50, callbacks=call)

        # Prediction
        y_cnn_probas = clf_cnn.predict(X_test_cnn)
        probas_cnn.append(y_cnn_probas)
        y_class = np.argmax(y_cnn_probas, axis=1)
        yscore = np.vstack((yscore, y_cnn_probas))

        # Calculate performance metrics
        acc, precision, npv, sensitivity, specificity, mcc, f1, tp, tn, fp, fn = calculate_performance(len(y_class), y_class, y[test])
        fpr, tpr, thresholds = roc_curve(y[test], y_cnn_probas[:, 1])
        roc_auc = auc(fpr, tpr)
        sepscore_cnn.append([acc, precision, npv, sensitivity, specificity, mcc, f1, roc_auc, tp, tn, fp, fn])
        print(f'{i} CNN: acc={acc:.6f}, precision={precision:.6f}, npv={npv:.6f}, sensitivity={sensitivity:.6f}, '
              f'specificity={specificity:.6f}, mcc={mcc:.6f}, f1={f1:.6f}, roc_auc={roc_auc:.6f}')

        # Save the model
        model_json = clf_cnn.to_json()
        with open(f"{output_base_dir}/CNN_BiLSTM_{str(i)}model.json", "w") as json_file:
            json_file.write(model_json)
        clf_cnn.save_weights(f"{output_base_dir}/CNN_BiLSTM_{str(i)}model.weights.h5")
        print("Saved model to disk")

    # Save ytest and yscore to CSV
    row = ytest.shape[0]
    ytest = ytest[np.array(range(1, row)), :]
    ytest_sum = pd.DataFrame(data=ytest)
    ytest_sum.to_csv(f'{output_base_dir}/ytest.csv')

    yscore_ = yscore[np.array(range(1, row)), :]
    yscore_sum = pd.DataFrame(data=yscore_)
    yscore_sum.to_csv(f'{output_base_dir}/yscore.csv')

    # Save results of cross-validation
    scores = np.array(sepscore_cnn)
    result1 = np.mean(scores, axis=0)
    H1 = result1.tolist()
    sepscore_cnn.append(H1)
    result = sepscore_cnn
    data_csv = pd.DataFrame(data=result, columns=['acc', 'precision', 'npv', 'sensitivity', 'specificity', 'mcc', 'f1', 'roc_auc', 'tp', 'tn', 'fp', 'fn'])
    data_csv.to_csv(f'{output_base_dir}/results_CV.csv', index=False)

    print(history)

    # Testing phase with another part of data
    test_data = data_.iloc[:, 1:]
    test_data = test_data.loc[2421:]
    ones_vector = np.ones(258)
    zeros_vector = np.zeros(227)
    yt = np.hstack((ones_vector, zeros_vector))

    Xt = scale(test_data)
    Xt = np.reshape(Xt, (-1, 1, input_dim))

    sepscores = []
    ytest = np.ones((1, 2)) * 0.5
    yscore = np.ones((1, 2)) * 0.5

    # Load and test saved models
    for i in range(10):
        with open(f"{output_base_dir}CNN_BiLSTM_{str(i)}model.json", 'r') as json_file:
            loaded_model_json = json_file.read()

        loaded_model = model_from_json(loaded_model_json)
        loaded_model.load_weights(f"{output_base_dir}CNN_BiLSTM_{i}model.weights.h5")
        print("Loaded model from disk")

        loaded_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        y_score = loaded_model.predict(Xt)
        y_class = categorical_probas_to_classes(y_score)

        y_test = to_categorical(yt)
        acc, precision, npv, sensitivity, specificity, mcc, f1, tp, tn, fp, fn = calculate_performance(len(y_class), y_class, yt)
        fpr, tpr, thresholds = roc_curve(yt, y_score[:, 1])
        roc_auc = auc(fpr, tpr)
        sepscores.append([acc, precision, npv, sensitivity, specificity, mcc, f1, roc_auc, tp, tn, fp, fn])
        print(f'{i} CNN Test: acc={acc:.6f}, precision={precision:.6f}, npv={npv:.6f}, sensitivity={sensitivity:.6f}, '
              f'specificity={specificity:.6f}, mcc={mcc:.6f}, f1={f1:.6f}, roc_auc={roc_auc:.6f}')

        # Save prediction results
        ytest = np.vstack((ytest, y_test))
        yscore = np.vstack((yscore, y_score))

    # Save testing results
    row = ytest.shape[0]
    ytest = ytest[np.array(range(1, row)), :]
    ytest_sum = pd.DataFrame(data=ytest)
    ytest_sum.to_csv(f'{output_base_dir}/ytest_test.csv')

    yscore_ = yscore[np.array(range(1, row)), :]
    yscore_sum = pd.DataFrame(data=yscore_)
    yscore_sum.to_csv(f'{output_base_dir}/yscore_test.csv')

    # Save testing results of cross-validation
    scores = np.array(sepscores)
    result1 = np.mean(scores, axis=0)
    H1 = result1.tolist()
    sepscores.append(H1)
    result = sepscores
    data_csv = pd.DataFrame(data=result, columns=['acc', 'precision', 'npv', 'sensitivity', 'specificity', 'mcc', 'f1', 'roc_auc', 'tp', 'tn', 'fp', 'fn'])
    data_csv.to_csv(f'{output_base_dir}/results_test.csv', index=False)
# Out:
# Epoch 1/50
# 273/273 [==============================] - 27s 79ms/step - loss: 0.2828 - accuracy: 0.8820 - val_loss: 0.2099 - val_accuracy: 0.9342 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 20s 73ms/step - loss: 0.1304 - accuracy: 0.9527 - val_loss: 0.1653 - val_accuracy: 0.9383 - lr: 0.0010
# Epoch 3/50
# 273/273 [==============================] - 20s 73ms/step - loss: 0.0936 - accuracy: 0.9697 - val_loss: 0.1294 - val_accuracy: 0.9424 - lr: 0.0010
# Epoch 4/50
# 273/273 [==============================] - 20s 73ms/step - loss: 0.0800 - accuracy: 0.9743 - val_loss: 0.0980 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 5/50
# 273/273 [==============================] - 20s 74ms/step - loss: 0.0849 - accuracy: 0.9711 - val_loss: 0.1105 - val_accuracy: 0.9588 - lr: 0.0010
# Epoch 6/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.0620 - accuracy: 0.9770 - val_loss: 0.0998 - val_accuracy: 0.9588 - lr: 0.0010
# Epoch 7/50
# 273/273 [==============================] - 21s 75ms/step - loss: 0.0693 - accuracy: 0.9780 - val_loss: 0.1433 - val_accuracy: 0.9671 - lr: 0.0010
# Epoch 8/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.0609 - accuracy: 0.9821 - val_loss: 0.1169 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 9/50
# 273/273 [==============================] - 20s 74ms/step - loss: 0.0536 - accuracy: 0.9830 - val_loss: 0.1263 - val_accuracy: 0.9630 - lr: 0.0010
# Epoch 10/50
50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.1383 - val_accuracy: 0.9630 - lr: 1.6000e-06
# 8/8 [==============================] - 1s 14ms/step
# 0 CNN: acc=0.962963, precision=0.961538, npv=0.964602, sensitivity=0.968992, specificity=0.956140, mcc=0.925636, f1=0.965251, roc_auc=0.993812
# Saved model to disk
# Epoch 1/50
# 273/273 [==============================] - 29s 77ms/step - loss: 0.2838 - accuracy: 0.8830 - val_loss: 0.2732 - val_accuracy: 0.8926 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 20s 74ms/step - loss: 0.1245 - accuracy: 0.9578 - val_loss: 0.2499 - val_accuracy: 0.9132 - lr: 0.0010
# Epoch 3/50
# 273/273 [==============================] - 20s 74ms/step - loss: 0.0830 - accuracy: 0.9743 - val_loss: 0.2491 - val_accuracy: 0.9339 - lr: 0.0010
# Epoch 4/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.0897 - accuracy: 0.9693 - val_loss: 0.3238 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 5/50
# 273/273 [==============================] - 20s 74ms/step - loss: 0.0687 - accuracy: 0.9775 - val_loss: 0.2978 - val_accuracy: 0.9215 - lr: 0.0010
# Epoch 6/50
# 273/273 [==============================] - 20s 74ms/step - loss: 0.0612 - accuracy: 0.9793 - val_loss: 0.1977 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch 7/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0601 - accuracy: 0.9803 - val_loss: 0.1700 - val_accuracy: 0.9545 - lr: 0.0010
# Epoch 8/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0591 - accuracy: 0.9803 - val_loss: 0.2209 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch 9/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0370 - accuracy: 0.9899 - val_loss: 0.2236 - val_accuracy: 0.9628 - lr: 0.0010
# Epoch 10/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0467 - accuracy: 0.9853 - val_loss: 0.2131 - val_accuracy: 0.9545 - lr: 0.0010
# Epoch 11/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0443 - accuracy: 0.9853 - val_loss: 0.1775 - val_accuracy: 0.9339 - lr: 0.0010
# Epoch 12/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0417 - accuracy: 0.9876 - val_loss: 0.2261 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 13/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0270 - accuracy: 0.9908 - val_loss: 0.2303 - val_accuracy: 0.9545 - lr: 2.0000e-04
# Epoch 14/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0222 - accuracy: 0.9913 - val_loss: 0.2410 - val_accuracy: 0.9545 - lr: 2.0000e-04
# Epoch 15/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0198 - accuracy: 0.9927 - val_loss: 0.2427 - val_accuracy: 0.9545 - lr: 2.0000e-04
# Epoch 16/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0183 - accuracy: 0.9927 - val_loss: 0.2340 - val_accuracy: 0.9545 - lr: 2.0000e-04
# Epoch 17/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.2538 - val_accuracy: 0.9504 - lr: 2.0000e-04
# Epoch 18/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0132 - accuracy: 0.9940 - val_loss: 0.2588 - val_accuracy: 0.9504 - lr: 4.0000e-05
# Epoch 19/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.2584 - val_accuracy: 0.9504 - lr: 4.0000e-05
# Epoch 20/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0148 - accuracy: 0.9940 - val_loss: 0.2610 - val_accuracy: 0.9545 - lr: 4.0000e-05
# Epoch 21/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0114 - accuracy: 0.9950 - val_loss: 0.2675 - val_accuracy: 0.9504 - lr: 4.0000e-05
# Epoch 22/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0118 - accuracy: 0.9950 - val_loss: 0.2758 - val_accuracy: 0.9504 - lr: 4.0000e-05
# Epoch 23/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.2771 - val_accuracy: 0.9504 - lr: 8.0000e-06
# Epoch 24/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0134 - accuracy: 0.9945 - val_loss: 0.2758 - val_accuracy: 0.9504 - lr: 8.0000e-06
# Epoch 25/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0141 - accuracy: 0.9922 - val_loss: 0.2797 - val_accuracy: 0.9504 - lr: 8.0000e-06
# Epoch 26/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0114 - accuracy: 0.9945 - val_loss: 0.2809 - val_accuracy: 0.9504 - lr: 8.0000e-06
# Epoch 27/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0112 - accuracy: 0.9936 - val_loss: 0.2807 - val_accuracy: 0.9545 - lr: 8.0000e-06
# Epoch 28/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0119 - accuracy: 0.9945 - val_loss: 0.2808 - val_accuracy: 0.9504 - lr: 1.6000e-06
# Epoch 29/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0107 - accuracy: 0.9954 - val_loss: 0.2811 - val_accuracy: 0.9504 - lr: 1.6000e-06
# Epoch 30/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0106 - accuracy: 0.9968 - val_loss: 0.2813 - val_accuracy: 0.9545 - lr: 1.6000e-06
# Epoch 31/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0128 - accuracy: 0.9950 - val_loss: 0.2811 - val_accuracy: 0.9587 - lr: 1.6000e-06
# Epoch 32/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0121 - accuracy: 0.9950 - val_loss: 0.2813 - val_accuracy: 0.9587 - lr: 1.6000e-06
# 8/8 [==============================] - 1s 30ms/step
# 1 CNN: acc=0.958678, precision=0.961240, npv=0.955752, sensitivity=0.961240, specificity=0.955752, mcc=0.916993, f1=0.961240, roc_auc=0.988955
# Saved model to disk
# Epoch 1/50
# 273/273 [==============================] - 33s 78ms/step - loss: 0.2691 - accuracy: 0.8922 - val_loss: 0.1762 - val_accuracy: 0.9339 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.1356 - accuracy: 0.9495 - val_loss: 0.1559 - val_accuracy: 0.9421 - lr: 0.0010
# Epoch 3/50
# 273/273 [==============================] - 21s 75ms/step - loss: 0.1003 - accuracy: 0.9683 - val_loss: 0.1528 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 4/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.0732 - accuracy: 0.9738 - val_loss: 0.1816 - val_accuracy: 0.9421 - lr: 0.0010
# Epoch 5/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.0627 - accuracy: 0.9789 - val_loss: 0.1992 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 6/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0675 - accuracy: 0.9766 - val_loss: 0.2070 - val_accuracy: 0.9421 - lr: 0.0010
# Epoch 7/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0682 - accuracy: 0.9780 - val_loss: 0.1934 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch 8/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0497 - accuracy: 0.9849 - val_loss: 0.2699 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 9/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0320 - accuracy: 0.9899 - val_loss: 0.2633 - val_accuracy: 0.9463 - lr: 2.0000e-04
# Epoch 10/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0314 - accuracy: 0.9894 - val_loss: 0.2538 - val_accuracy: 0.9463 - lr: 2.0000e-04
# Epoch 11/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0297 - accuracy: 0.9904 - val_loss: 0.2653 - val_accuracy: 0.9463 - lr: 2.0000e-04
# Epoch 12/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0253 - accuracy: 0.9913 - val_loss: 0.2671 - val_accuracy: 0.9463 - lr: 2.0000e-04
# Epoch 13/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0209 - accuracy: 0.9922 - val_loss: 0.2841 - val_accuracy: 0.9421 - lr: 2.0000e-04
# Epoch 14/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0161 - accuracy: 0.9945 - val_loss: 0.2897 - val_accuracy: 0.9421 - lr: 4.0000e-05
# Epoch 15/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0182 - accuracy: 0.9945 - val_loss: 0.2886 - val_accuracy: 0.9421 - lr: 4.0000e-05
# Epoch 16/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.2884 - val_accuracy: 0.9463 - lr: 4.0000e-05
# Epoch 17/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.2941 - val_accuracy: 0.9421 - lr: 4.0000e-05
# Epoch 18/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0147 - accuracy: 0.9959 - val_loss: 0.3029 - val_accuracy: 0.9421 - lr: 4.0000e-05
# Epoch 19/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0157 - accuracy: 0.9931 - val_loss: 0.3034 - val_accuracy: 0.9421 - lr: 8.0000e-06
# Epoch 20/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0134 - accuracy: 0.9945 - val_loss: 0.3051 - val_accuracy: 0.9421 - lr: 8.0000e-06
# Epoch 21/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0134 - accuracy: 0.9936 - val_loss: 0.3058 - val_accuracy: 0.9421 - lr: 8.0000e-06
# Epoch 22/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0161 - accuracy: 0.9940 - val_loss: 0.3061 - val_accuracy: 0.9421 - lr: 8.0000e-06
# Epoch 23/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0139 - accuracy: 0.9945 - val_loss: 0.3069 - val_accuracy: 0.9421 - lr: 8.0000e-06
# Epoch 24/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0131 - accuracy: 0.9940 - val_loss: 0.3071 - val_accuracy: 0.9421 - lr: 1.6000e-06
# Epoch 25/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0161 - accuracy: 0.9940 - val_loss: 0.3075 - val_accuracy: 0.9421 - lr: 1.6000e-06
# Epoch 26/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0144 - accuracy: 0.9927 - val_loss: 0.3077 - val_accuracy: 0.9421 - lr: 1.6000e-06
# Epoch 27/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0153 - accuracy: 0.9940 - val_loss: 0.3074 - val_accuracy: 0.9421 - lr: 1.6000e-06
# Epoch 28/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0152 - accuracy: 0.9940 - val_loss: 0.3075 - val_accuracy: 0.9421 - lr: 1.6000e-06
# 8/8 [==============================] - 1s 16ms/step
# 2 CNN: acc=0.942149, precision=0.952756, npv=0.930435, sensitivity=0.937984, specificity=0.946903, mcc=0.884039, f1=0.945312, roc_auc=0.988818
# Saved model to disk
# Epoch 1/50
# 273/273 [==============================] - 28s 78ms/step - loss: 0.2871 - accuracy: 0.8844 - val_loss: 0.1485 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.1373 - accuracy: 0.9555 - val_loss: 0.1382 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch
50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0132 - accuracy: 0.9931 - val_loss: 0.2361 - val_accuracy: 0.9669 - lr: 8.0000e-06
# Epoch 27/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0100 - accuracy: 0.9954 - val_loss: 0.2377 - val_accuracy: 0.9628 - lr: 8.0000e-06
# Epoch 28/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0105 - accuracy: 0.9950 - val_loss: 0.2391 - val_accuracy: 0.9587 - lr: 8.0000e-06
# Epoch 29/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0106 - accuracy: 0.9945 - val_loss: 0.2409 - val_accuracy: 0.9587 - lr: 8.0000e-06
# Epoch 30/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0112 - accuracy: 0.9936 - val_loss: 0.2411 - val_accuracy: 0.9587 - lr: 1.6000e-06
# Epoch 31/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0115 - accuracy: 0.9940 - val_loss: 0.2413 - val_accuracy: 0.9587 - lr: 1.6000e-06
# Epoch 32/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0095 - accuracy: 0.9954 - val_loss: 0.2416 - val_accuracy: 0.9587 - lr: 1.6000e-06
# Epoch 33/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0080 - accuracy: 0.9959 - val_loss: 0.2421 - val_accuracy: 0.9587 - lr: 1.6000e-06
# Epoch 34/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0127 - accuracy: 0.9940 - val_loss: 0.2422 - val_accuracy: 0.9587 - lr: 1.6000e-06
# 8/8 [==============================] - 1s 14ms/step
# 3 CNN: acc=0.958678, precision=0.961240, npv=0.955752, sensitivity=0.961240, specificity=0.955752, mcc=0.916993, f1=0.961240, roc_auc=0.993483
# Saved model to disk
# Epoch 1/50
# 273/273 [==============================] - 34s 79ms/step - loss: 0.2743 - accuracy: 0.8908 - val_loss: 0.1620 - val_accuracy: 0.9298 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 21s 75ms/step - loss: 0.1367 - accuracy: 0.9523 - val_loss: 0.1237 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 3/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.0870 - accuracy: 0.9725 - val_loss: 0.0722 - val_accuracy: 0.9711 - lr: 0.0010
# Epoch 4/50
# 273/273 [==============================] - 21s 77ms/step - loss: 0.0814 - accuracy: 0.9761 - val_loss: 0.1242 - val_accuracy: 0.9628 - lr: 0.0010
# Epoch 5/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0660 - accuracy: 0.9771 - val_loss: 0.1342 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 6/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0648 - accuracy: 0.9807 - val_loss: 0.0988 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 7/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0611 - accuracy: 0.9761 - val_loss: 0.1513 - val_accuracy: 0.9545 - lr: 0.0010
# Epoch 8/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0602 - accuracy: 0.9816 - val_loss: 0.1005 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 9/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0431 - accuracy: 0.9853 - val_loss: 0.0921 - val_accuracy: 0.9711 - lr: 2.0000e-04
# Epoch 10/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0254 - accuracy: 0.9894 - val_loss: 0.0853 - val_accuracy: 0.9793 - lr: 2.0000e-04
# Epoch 11/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0229 - accuracy: 0.9913 - val_loss: 0.0850 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 12/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0176 - accuracy: 0.9931 - val_loss: 0.0944 - val_accuracy: 0.9835 - lr: 2.0000e-04
# Epoch 13/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0182 - accuracy: 0.9945 - val_loss: 0.1003 - val_accuracy: 0.9835 - lr: 2.0000e-04
# Epoch 14/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.
50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0150 - accuracy: 0.9931 - val_loss: 0.1022 - val_accuracy: 0.9711 - lr: 4.0000e-05
# Epoch 19/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0126 - accuracy: 0.9954 - val_loss: 0.1053 - val_accuracy: 0.9669 - lr: 4.0000e-05
# Epoch 20/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0106 - accuracy: 0.9954 - val_loss: 0.1097 - val_accuracy: 0.9669 - lr: 4.0000e-05
# Epoch 21/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0111 - accuracy: 0.9940 - val_loss: 0.1128 - val_accuracy: 0.9669 - lr: 4.0000e-05
# Epoch 22/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0137 - accuracy: 0.9940 - val_loss: 0.1129 - val_accuracy: 0.9669 - lr: 8.0000e-06
# Epoch 23/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0139 - accuracy: 0.9940 - val_loss: 0.1134 - val_accuracy: 0.9669 - lr: 8.0000e-06
# Epoch 24/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0133 - accuracy: 0.9940 - val_loss: 0.1130 - val_accuracy: 0.9669 - lr: 8.0000e-06
# Epoch 25/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0144 - accuracy: 0.9945 - val_loss: 0.1131 - val_accuracy: 0.9669 - lr: 8.0000e-06
# Epoch 26/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0128 - accuracy: 0.9950 - val_loss: 0.1136 - val_accuracy: 0.9669 - lr: 8.0000e-06
# Epoch 27/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0120 - accuracy: 0.9950 - val_loss: 0.1137 - val_accuracy: 0.9669 - lr: 1.6000e-06
# Epoch 28/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0130 - accuracy: 0.9950 - val_loss: 0.1138 - val_accuracy: 0.9669 - lr: 1.6000e-06
# Epoch 29/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0111 - accuracy: 0.9936 - val_loss: 0.1140 - val_accuracy: 0.9669 - lr: 1.6000e-06
# Epoch 30/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0138 - accuracy: 0.9931 - val_loss: 0.1142 - val_accuracy: 0.9669 - lr: 1.6000e-06
# Epoch 31/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0136 - accuracy: 0.9936 - val_loss: 0.1144 - val_accuracy: 0.9669 - lr: 1.6000e-06
# 8/8 [==============================] - 2s 27ms/step
# 6 CNN: acc=0.966942, precision=0.991870, npv=0.941176, sensitivity=0.945736, specificity=0.991150, mcc=0.934965, f1=0.968254, roc_auc=0.992660
# Saved model to disk
# Epoch 1/50
# 273/273 [==============================] - 36s 80ms/step - loss: 0.2772 - accuracy: 0.8908 - val_loss: 0.2029 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 21s 75ms/step - loss: 0.1261 - accuracy: 0.9569 - val_loss: 0.2049 - val_accuracy: 0.9380 - lr: 0.0010
# Epoch 3/50
# 273/273 [==============================] - 21s 75ms/step - loss: 0.0892 - accuracy: 0.9688 - val_loss: 0.1574 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 4/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0771 - accuracy: 0.9693 - val_loss: 0.1747 - val_accuracy: 0.9463 - lr: 0.0010
# Epoch 5/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0539 - accuracy: 0.9803 - val_loss: 0.2165 - val_accuracy: 0.9628 - lr: 0.0010
# Epoch 6/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0610 - accuracy: 0.9789 - val_loss: 0.3640 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 7/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0472 - accuracy: 0.9816 - val_loss: 0.2106 - val_accuracy: 0.9545 - lr: 0.0010
# Epoch 8/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0468 - accuracy: 0.9849 - val_loss: 0.2287 - val_accuracy: 0.9628 - lr: 0.0010
# Epoch 9/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0384 - accuracy: 0.9881 - val_loss: 0.2038 - val_accuracy: 0.9669 - lr: 2.0000e-04
# Epoch 10/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0291 - accuracy: 0.9913 - val_loss: 0.2126 - val_accuracy: 0.9628 - lr: 2.0000e-04
# Epoch 11/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0175 - accuracy: 0.9917 - val_loss: 0.2383 - val_accuracy: 0.9587 - lr: 2.0000e-04
# Epoch 12/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0174 - accuracy: 0.9917 - val_loss: 0.2227 - val_accuracy: 0.9669 - lr: 2.0000e-04
# Epoch 13/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0175 - accuracy: 0.9927 - val_loss: 0.2385 - val_accuracy: 0.9669 - lr: 2.0000e-04
# Epoch 14/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0141 - accuracy: 0.9945 - val_loss: 0.2426 - val_accuracy: 0.9669 - lr: 4.0000e-05
# Epoch 15/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0125 - accuracy: 0.9954 - val_loss: 0.2489 - val_accuracy: 0.9669 - lr: 4.0000e-05
# Epoch 16/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0122 - accuracy: 0.9936 - val_loss: 0.2582 - val_accuracy: 0.9669 - lr: 4.0000e-05
# Epoch 17/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0129 - accuracy: 0.9917 - val_loss: 0.2681 - val_accuracy: 0.9669 - lr: 4.0000e-05
# Epoch 18/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0105 - accuracy: 0.9945 - val_loss: 0.2717 - val_accuracy: 0.9711 - lr: 4.0000e-05
# Epoch 19/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0116 - accuracy: 0.9940 - val_loss: 0.2723 - val_accuracy: 0.9711 - lr: 8.0000e-06
# Epoch 20/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0118 - accuracy: 0.9940 - val_loss: 0.2723 - val_accuracy: 0.9711 - lr: 8.0000e-06
# Epoch 21/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0109 - accuracy: 0.9936 - val_loss: 0.2728 - val_accuracy: 0.9711 - lr: 8.0000e-06
# Epoch 22/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0113 - accuracy: 0.9931 - val_loss: 0.2749 - val_accuracy: 0.9711 - lr: 8.0000e-06
# Epoch 23/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0107 - accuracy: 0.9940 - val_loss: 0.2765 - val_accuracy: 0.9711 - lr: 8.0000e-06
# Epoch 24/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0084 - accuracy: 0.9954 - val_loss: 0.2773 - val_accuracy: 0.9711 - lr: 1.6000e-06
# Epoch 25/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0113 - accuracy: 0.9945 - val_loss: 0.2777 - val_accuracy: 0.9711 - lr: 1.6000e-06
# Epoch 26/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0117 - accuracy: 0.9940 - val_loss: 0.2781 - val_accuracy: 0.9711 - lr: 1.6000e-06
# Epoch 27/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0122 - accuracy: 0.9922 - val_loss: 0.2782 - val_accuracy: 0.9711 - lr: 1.6000e-06
# Epoch 28/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0119 - accuracy: 0.9954 - val_loss: 0.2788 - val_accuracy: 0.9711 - lr: 1.6000e-06
# 8/8 [==============================] - 1s 27ms/step
# 7 CNN: acc=0.971074, precision=1.000000, npv=0.941667, sensitivity=0.945736, specificity=1.000000, mcc=0.943699, f1=0.972112, roc_auc=0.989298
# Saved model to disk
# Epoch 1/50
# 273/273 [==============================] - 28s 78ms/step - loss: 0.2820 - accuracy: 0.8765 - val_loss: 0.1635 - val_accuracy: 0.9545 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 20s 75ms/step - loss: 0.1318 - accuracy: 0.9564 - val_loss: 0.1331 - val_accuracy: 0.9298 - lr: 0.0010
# Epoch 3/50
# 273/273 [==============================] - 21s 76ms/step - loss: 0.1079 - accuracy: 0.9624 - val_loss: 0.1049 - val_accuracy: 0.9669 - lr: 0.0010
# Epoch 4/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0798 - accuracy: 0.9720 - val_loss: 0.1007 - val_accuracy: 0.9628 - lr: 0.0010
# Epoch 5/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0732 - accuracy: 0.9761 - val_loss: 0.1201 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 6/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0685 - accuracy: 0.9793 - val_loss: 0.0809 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 7/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0530 - accuracy: 0.9839 - val_loss: 0.0971 - val_accuracy: 0.9669 - lr: 0.0010
# Epoch 8/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0430 - accuracy: 0.9853 - val_loss: 0.0715 - val_accuracy: 0.9876 - lr: 0.0010
# Epoch 9/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0477 - accuracy: 0.9830 - val_loss: 0.0638 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 10/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0631 - accuracy: 0.9761 - val_loss: 0.0677 - val_accuracy: 0.9711 - lr: 0.0010
# Epoch 11/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 0.0863 - val_accuracy: 0.9793 - lr: 0.0010
# Epoch 12/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0529 - accuracy: 0.9807 - val_loss: 0.0577 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 13/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0592 - accuracy: 0.9812 - val_loss: 0.1011 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 14/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0487 - accuracy: 0.9826 - val_loss: 0.0637 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 15/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0437 - accuracy: 0.9872 - val_loss: 0.0691 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 16/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0386 - accuracy: 0.9872 - val_loss: 0.0964 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 17/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0306 - accuracy: 0.9890 - val_loss: 0.0768 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 18/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0187 - accuracy: 0.9945 - val_loss: 0.0808 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 19/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0182 - accuracy: 0.9931 - val_loss: 0.0751 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 20/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0260 - accuracy: 0.9894 - val_loss: 0.0780 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 21/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0192 - accuracy: 0.9927 - val_loss: 0.0772 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 22/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0165 - accuracy: 0.9917 - val_loss: 0.0794 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 23/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0155 - accuracy: 0.9936 - val_loss: 0.0791 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 24/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0136 - accuracy: 0.9927 - val_loss: 0.0802 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 25/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0119 - accuracy: 0.9945 - val_loss: 0.0819 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 26/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0126 - accuracy: 0.9936 - val_loss: 0.0828 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 27/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0109 - accuracy: 0.9950 - val_loss: 0.0830 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 28/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 0.0825 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 29/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0099 - accuracy: 0.9945 - val_loss: 0.0830 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 30/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0143 - accuracy: 0.9940 - val_loss: 0.0828 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 31/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0142 - accuracy: 0.9922 - val_loss: 0.0826 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 32/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.0835 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 33/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0112 - accuracy: 0.9950 - val_loss: 0.0835 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 34/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0836 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 35/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0100 - accuracy: 0.9950 - val_loss: 0.0838 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 36/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0097 - accuracy: 0.9959 - val_loss: 0.0839 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 37/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0133 - accuracy: 0.9940 - val_loss: 0.0838 - val_accuracy: 0.9752 - lr: 1.6000e-06
# 8/8 [==============================] - 1s 25ms/step
# 8 CNN: acc=0.975207, precision=0.984127, npv=0.965517, sensitivity=0.968750, specificity=0.982456, mcc=0.950425, f1=0.976378, roc_auc=0.997533
# Saved model to disk
# Epoch 1/50
# 273/273 [==============================] - 34s 80ms/step - loss: 0.2817 - accuracy: 0.8802 - val_loss: 0.1698 - val_accuracy: 0.9587 - lr: 0.0010
# Epoch 2/50
# 273/273 [==============================] - 21s 76ms/step - loss: 0.1339 - accuracy: 0.9569 - val_loss: 0.1590 - val_accuracy: 0.9545 - lr: 0.0010
# Epoch 3/50
# 273/273 [==============================] - 21s 75ms/step - loss: 0.0966 - accuracy: 0.9683 - val_loss: 0.1118 - val_accuracy: 0.9669 - lr: 0.0010
# Epoch 4/50
# 273/273 [==============================] - 21s 77ms/step - loss: 0.0770 - accuracy: 0.9738 - val_loss: 0.1054 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 5/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0771 - accuracy: 0.9738 - val_loss: 0.0908 - val_accuracy: 0.9752 - lr: 0.0010
# Epoch 6/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0606 - accuracy: 0.9816 - val_loss: 0.1371 - val_accuracy: 0.9711 - lr: 0.0010
# Epoch 7/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0538 - accuracy: 0.9812 - val_loss: 0.1185 - val_accuracy: 0.9711 - lr: 0.0010
# Epoch 8/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0567 - accuracy: 0.9807 - val_loss: 0.1416 - val_accuracy: 0.9504 - lr: 0.0010
# Epoch 9/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0555 - accuracy: 0.9830 - val_loss: 0.0984 - val_accuracy: 0.9793 - lr: 0.0010
# Epoch 10/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0413 - accuracy: 0.9876 - val_loss: 0.1094 - val_accuracy: 0.9711 - lr: 0.0010
# Epoch 11/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0367 - accuracy: 0.9885 - val_loss: 0.1128 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 12/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0230 - accuracy: 0.9904 - val_loss: 0.1109 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 13/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 0.1101 - val_accuracy: 0.9711 - lr: 2.0000e-04
# Epoch 14/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0191 - accuracy: 0.9922 - val_loss: 0.1240 - val_accuracy: 0.9711 - lr: 2.0000e-04
# Epoch 15/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0197 - accuracy: 0.9913 - val_loss: 0.1142 - val_accuracy: 0.9752 - lr: 2.0000e-04
# Epoch 16/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0156 - accuracy: 0.9927 - val_loss: 0.1202 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 17/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0204 - accuracy: 0.9917 - val_loss: 0.1230 - val_accuracy: 0.9711 - lr: 4.0000e-05
# Epoch 18/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0149 - accuracy: 0.9945 - val_loss: 0.1252 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 19/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0156 - accuracy: 0.9940 - val_loss: 0.1243 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 20/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0173 - accuracy: 0.9922 - val_loss: 0.1296 - val_accuracy: 0.9752 - lr: 4.0000e-05
# Epoch 21/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0120 - accuracy: 0.9936 - val_loss: 0.1293 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 22/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0148 - accuracy: 0.9940 - val_loss: 0.1300 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 23/50
# 273/273 [==============================] - 22s 81ms/step - loss: 0.0128 - accuracy: 0.9950 - val_loss: 0.1311 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 24/50
# 273/273 [==============================] - 22s 80ms/step - loss: 0.0139 - accuracy: 0.9936 - val_loss: 0.1325 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 25/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0120 - accuracy: 0.9950 - val_loss: 0.1333 - val_accuracy: 0.9752 - lr: 8.0000e-06
# Epoch 26/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0125 - accuracy: 0.9945 - val_loss: 0.1334 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 27/50
# 273/273 [==============================] - 21s 79ms/step - loss: 0.0113 - accuracy: 0.9954 - val_loss: 0.1335 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 28/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0103 - accuracy: 0.9950 - val_loss: 0.1337 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 29/50
# 273/273 [==============================] - 22s 79ms/step - loss: 0.0132 - accuracy: 0.9950 - val_loss: 0.1340 - val_accuracy: 0.9752 - lr: 1.6000e-06
# Epoch 30/50
# 273/273 [==============================] - 21s 78ms/step - loss: 0.0113 - accuracy: 0.9950 - val_loss: 0.1341 - val_accuracy: 0.9752 - lr: 1.6000e-06
# 8/8 [==============================] - 2s 28ms/step
# 9 CNN: acc=0.975207, precision=0.962121, npv=0.990909, sensitivity=0.992187, specificity=0.956140, mcc=0.950676, f1=0.976923, roc_auc=0.994072
# Saved model to disk
# <keras.src.callbacks.History object at 0x000000009285C520>
# Loaded model from disk
# 16/16 [==============================] - 3s 23ms/step
# 0 CNN Test: acc=0.971134, precision=0.976562, npv=0.965065, sensitivity=0.968992, specificity=0.973568, mcc=0.942094, f1=0.972763, roc_auc=0.993068
# Loaded model from disk
# 16/16 [==============================] - 2s 29ms/step
# 1 CNN Test: acc=0.967010, precision=0.972656, npv=0.960699, sensitivity=0.965116, specificity=0.969163, mcc=0.933817, f1=0.968872, roc_auc=0.990472
# Loaded model from disk
# 16/16 [==============================] - 3s 24ms/step
# 2 CNN Test: acc=0.971134, precision=0.980315, npv=0.961039, sensitivity=0.965116, specificity=0.977974, mcc=0.942221, f1=0.972656, roc_auc=0.989738
# Loaded model from disk
# 16/16 [==============================] - 2s 25ms/step
# 3 CNN Test: acc=0.967010, precision=0.976378, npv=0.956710, sensitivity=0.961240, specificity=0.973568, mcc=0.933948, f1=0.968750, roc_auc=0.993409
# Loaded model from disk
# 16/16 [==============================] - 1s 11ms/step
# 4 CNN Test: acc=0.967010, precision=0.976378, npv=0.956710, sensitivity=0.961240, specificity=0.973568, mcc=0.933948, f1=0.968750, roc_auc=0.992513
# Loaded model from disk
# 16/16 [==============================] - 1s 14ms/step
# 5 CNN Test: acc=0.958763, precision=0.972222, npv=0.944206, sensitivity=0.949612, specificity=0.969163, mcc=0.917601, f1=0.960784, roc_auc=0.988918
# Loaded model from disk
# 16/16 [==============================] - 1s 12ms/step
# 6 CNN Test: acc=0.960825, precision=0.979920, npv=0.940678, sensitivity=0.945736, specificity=0.977974, mcc=0.922153, f1=0.962525, roc_auc=0.990054
# Loaded model from disk
# 16/16 [==============================] - 2s 20ms/step
# 7 CNN Test: acc=0.971134, precision=0.984127, npv=0.957082, sensitivity=0.961240, specificity=0.982379, mcc=0.942413, f1=0.972549, roc_auc=0.992325
# Loaded model from disk
# 16/16 [==============================] - 1s 13ms/step
# 8 CNN Test: acc=0.973196, precision=0.980392, npv=0.965217, sensitivity=0.968992, specificity=0.977974, mcc=0.946287, f1=0.974659, roc_auc=0.992982
# Loaded model from disk
# 16/16 [==============================] - 1s 11ms/step
# 9 CNN Test: acc=0.958763, precision=0.968504, npv=0.948052, sensitivity=0.953488, specificity=0.964758, mcc=0.917401, f1=0.960937, roc_auc=0.991198
